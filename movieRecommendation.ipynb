# %% [markdown]
# <a href="https://colab.research.google.com/github/prabha-716/Movie_recommendation-project/blob/main/movieRecommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import difflib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
movies_data=pd.read_csv('/content/movies.csv')

# %%
movies_data.shape
# Out:
# (4803, 24)

# %% [markdown]
# selecting features

# %%
movies_data.head()
# Out:
#    index  ...           director
# 0      0  ...      James Cameron
# 1      1  ...     Gore Verbinski
# 2      2  ...         Sam Mendes
# 3      3  ...  Christopher Nolan
# 4      4  ...     Andrew Stanton
#
# [5 rows x 24 columns]

# %%
selected=['genres',"keywords","tagline","cast","director","original_title"]

for feature in selected:
  movies_data[feature]=movies_data[feature].fillna('')

# %%
combined_features=movies_data['genres']+' '+movies_data['keywords']+' '+movies_data['tagline']+' '+movies_data['cast']+' '+movies_data['director']+' '+movies_data["original_title"]

# %%
vectorizer=TfidfVectorizer()

# %%
feature_vectors=vectorizer.fit_transform(combined_features)

# %%
similarity=cosine_similarity(feature_vectors)

print(similarity)
# Out:
# [[1.         0.07355546 0.03531556 ... 0.         0.         0.        ]
#  [0.07355546 1.         0.02790734 ... 0.04430756 0.         0.        ]
#  [0.03531556 0.02790734 1.         ... 0.         0.04635788 0.        ]
#  ...
#  [0.         0.04430756 0.         ... 1.         0.         0.05548941]
#  [0.         0.         0.04635788 ... 0.         1.         0.        ]
#  [0.         0.         0.         ... 0.05548941 0.         1.        ]]

# %%
user_input=input("Movie Name : ")

all_titles=movies_data['title'].tolist()

close_match=difflib.get_close_matches(user_input,all_titles)
closest=close_match[0]

index_of_movie=movies_data[movies_data.title == closest]['index'].values[0]

similarity_score = [(i, float(score)) for i, score in enumerate(similarity[index_of_movie])]

sorted_similarity_score=sorted(similarity_score,key=lambda x:x[1],reverse=True)

print("Suggested Movies : \n")

i=1

for movie in sorted_similarity_score:
  index=movie[0]
  title_of_movie=movies_data[movies_data.index==index]['title'].values[0]

  if (i<30):
    print(i,'.',title_of_movie)
    i+=1
# Out:
# Movie Name : avengers
# Suggested Movies :
#
# 1 . The Avengers
# 2 . Avengers: Age of Ultron
# 3 . Captain America: The Winter Soldier
# 4 . Iron Man 2
# 5 . Captain America: Civil War
# 6 . Thor: The Dark World
# 7 . X-Men
# 8 . The Incredible Hulk
# 9 . X-Men: Apocalypse
# 10 . Ant-Man
# 11 . Thor
# 12 . X2
# 13 . Deadpool
# 14 . X-Men: The Last Stand
# 15 . Captain America: The First Avenger
# 16 . The Amazing Spider-Man 2
# 17 . Iron Man
# 18 . X-Men: Days of Future Past
# 19 . Iron Man 3
# 20 . The Image Revolution
# 21 . The Spirit
# 22 . Superman II
# 23 . Man of Steel
# 24 . X-Men: First Class
# 25 . Guardians of the Galaxy
# 26 . Serenity
# 27 . The Jungle Book
# 28 . Spawn
# 29 . What's Your Number?
